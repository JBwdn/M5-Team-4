# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
od600_df = pd.read_excel(open('2019_12_06_MResSSB_OD600.xlsx'))
# Out:
#                                             User: USER  Unnamed: 1 Unnamed: 2  \
# 0    Path: C:\Program Files (x86)\BMG\Omega\User\Data\         NaN        NaN
# 1                                         Test ID: 224         NaN        NaN
# 2                                Test Name: Ari-Abs600         NaN        NaN
# 3                                     Date: 06/12/2019         NaN        NaN
# 4                                       Time: 13:13:22         NaN        NaN
# ..                                                 ...         ...        ...
# 102                                                H08  Sample X92      0.398
# 103                                                H09  Sample X93      0.396
# 104                                                H10  Sample X94      0.092
# 105                                                H11  Sample X95      0.092
# 106                                                H12  Sample X96        0.1
#
# ...
