# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
od600_df = pd.read_excel(open('BFP_modified.xlsx', 'rb'), index_col=1)

# %%
od600_df
# Out:
#                                                                  User: USER  \
# NaN                       Path: C:\Program Files (x86)\BMG\CLARIOstar\Us...
# NaN                                                           Test ID: 1996
# NaN                                            Test Name: mTag_BFP_Standard
# NaN                                                        Date: 06/12/2019
# NaN                                                          Time: 13:15:37
# NaN                                   ID2: Wizard script `MRes SSB`, Prot.3
# NaN                                                       Fluorescence (FI)
# NaN                                                                     NaN
# NaN                                                                     NaN
# Raw Data (400-20/460-40)                                               Well
# 0 h                                                                     NaN
# ...
